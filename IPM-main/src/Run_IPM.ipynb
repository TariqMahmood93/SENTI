# %%
import pandas as pd
import os
import re
import torch
import shutil

# Set GPU
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
print("CUDA available:", torch.cuda.is_available())
# Out:
# CUDA available: True

# %%
# 1) build your variables in Python
dataset  = "mammogram"
folder   = "one_third_step_10%"
seed     = 584
training = "fixed" # "fixed" or "Retraining"
split    = "70_30"
path      = f"/root/workspace/IPM-main/Dynamic_data/{dataset}/{split}/{training}_{folder}"
code_file = f"/root/workspace/IPM-main/src/ipm_multi_v5_with_{training}.py"

# 2) %run with $‑expansion of Python variables
# %run $code_file \
  --model_type roberta \
  --model_name_or_path deepset/roberta-base-squad2 \
  --data_dir $path \
  --dataset $dataset \
  --train_batch_size 32 \
  --eval_batch_size 32 \
  --max_seq_length 75 \
  --num_epochs 2 \
  --seed $seed
  
  
  # after your %run finishes
import gc, torch
gc.collect()
torch.cuda.empty_cache()
torch.cuda.ipc_collect()  # if you used multiprocessing
# Out:
# CUDA available: True
# *** parsed configuration from command line and combine with constants ***
# argument: data_dir=/root/workspace/IPM-main/Dynamic_data/mammogram/70_30/fixed_one_third_step_10%
# argument: model_name_or_path=deepset/roberta-base-squad2
# argument: model_type=roberta
# argument: do_lower_case=True
# argument: max_seq_length=75
# argument: train_batch_size=32
# argument: eval_batch_size=32
# argument: num_epochs=2.0
# argument: save_model_after_epoch=False
# argument: learning_rate=2e-05
# argument: adam_eps=1e-08
# argument: warmup_steps=0
# argument: max_grad_norm=1.0
# argument: weight_decay=0.0
# argument: dataset=mammogram
# argument: missing_rate=10
# argument: neg_num=3
# argument: select_method=top1
# argument: nn_num=1000
# argument: select_threshold=0.0
# argument: training_ratio=1.0
# argument: pretrained=pre
# argument: file_ix=all
# argument: oov_method=bpe
# argument: seed=584
# argument: data_path=/root/workspace/IPM-main/Dynamic_data/mammogram/70_30/fixed_one_third_step_10%
# argument: model_output_dir=experiments
# We use the device: 'cuda' and 1 gpu's. Important: distributed and 16-bits training is currently not implemented!
# Using device: cuda with 1 GPUs
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:486: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   truth['text_a'] = truth[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:486: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   truth['text_a'] = truth[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:486: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   truth['text_a'] = truth[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:486: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   truth['text_a'] = truth[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/.pyenv/versions/tariq/lib/python3.10/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at deepset/roberta-base-squad2 and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /root/.pyenv/versions/tariq/lib/python3.10/site-packages/transformers/optimization.py:588: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# Iteration: 100%|██████████| 6/6 [00:00<00:00, 10.95it/s]
# Evaluating: 100%|██████████| 3/3 [00:00<00:00, 39.69it/s]
# /root/.pyenv/versions/tariq/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /root/.pyenv/versions/tariq/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /root/.pyenv/versions/tariq/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Iteration: 100%|██████████| 6/6 [00:00<00:00, 11.00it/s]
# Evaluating: 100%|██████████| 3/3 [00:00<00:00, 39.88it/s]
# /root/.pyenv/versions/tariq/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /root/.pyenv/versions/tariq/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /root/.pyenv/versions/tariq/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Epoch: 100%|██████████| 2/2 [00:01<00:00,  1.56it/s]
# /root/.pyenv/versions/tariq/lib/python3.10/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at deepset/roberta-base-squad2 and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /root/.pyenv/versions/tariq/lib/python3.10/site-packages/transformers/optimization.py:588: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# Iteration: 100%|██████████| 7/7 [00:00<00:00, 11.46it/s]
# Evaluating: 100%|██████████| 3/3 [00:00<00:00, 37.84it/s]
# /root/.pyenv/versions/tariq/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /root/.pyenv/versions/tariq/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /root/.pyenv/versions/tariq/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /root/.pyenv/versions/tariq/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /root/.pyenv/versions/tariq/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /root/.pyenv/versions/tariq/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Iteration: 100%|██████████| 7/7 [00:00<00:00, 11.46it/s]
# Evaluating: 100%|██████████| 3/3 [00:00<00:00, 38.38it/s]
# /root/workspace/IPM-main/src/evaluation.py:72: RuntimeWarning: invalid value encountered in scalar divide
#   f1 = 2*precision*recall / (precision+recall)
# /root/.pyenv/versions/tariq/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /root/.pyenv/versions/tariq/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /root/.pyenv/versions/tariq/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /root/.pyenv/versions/tariq/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /root/.pyenv/versions/tariq/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /root/.pyenv/versions/tariq/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Epoch: 100%|██████████| 2/2 [00:01<00:00,  1.41it/s]
# /root/.pyenv/versions/tariq/lib/python3.10/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at deepset/roberta-base-squad2 and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /root/.pyenv/versions/tariq/lib/python3.10/site-packages/transformers/optimization.py:588: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# Iteration: 100%|██████████| 6/6 [00:00<00:00, 10.85it/s]
# Evaluating: 100%|██████████| 3/3 [00:00<00:00, 39.55it/s]
# /root/.pyenv/versions/tariq/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /root/.pyenv/versions/tariq/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /root/.pyenv/versions/tariq/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Iteration: 100%|██████████| 6/6 [00:00<00:00, 10.86it/s]
# Evaluating: 100%|██████████| 3/3 [00:00<00:00, 40.07it/s]
# /root/.pyenv/versions/tariq/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /root/.pyenv/versions/tariq/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /root/.pyenv/versions/tariq/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Epoch: 100%|██████████| 2/2 [00:01<00:00,  1.54it/s]
# /root/.pyenv/versions/tariq/lib/python3.10/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at deepset/roberta-base-squad2 and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /root/.pyenv/versions/tariq/lib/python3.10/site-packages/transformers/optimization.py:588: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# Iteration: 100%|██████████| 6/6 [00:00<00:00, 10.82it/s]
# Evaluating: 100%|██████████| 3/3 [00:00<00:00, 39.57it/s]
# /root/.pyenv/versions/tariq/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /root/.pyenv/versions/tariq/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /root/.pyenv/versions/tariq/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Iteration: 100%|██████████| 6/6 [00:00<00:00, 10.87it/s]
# Evaluating: 100%|██████████| 3/3 [00:00<00:00, 40.25it/s]
# /root/.pyenv/versions/tariq/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /root/.pyenv/versions/tariq/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /root/.pyenv/versions/tariq/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Epoch: 100%|██████████| 2/2 [00:01<00:00,  1.54it/s]
# /root/.pyenv/versions/tariq/lib/python3.10/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at deepset/roberta-base-squad2 and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /root/.pyenv/versions/tariq/lib/python3.10/site-packages/transformers/optimization.py:588: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# Iteration: 100%|██████████| 6/6 [00:00<00:00, 10.75it/s]
# Evaluating: 100%|██████████| 3/3 [00:00<00:00, 39.69it/s]
# /root/.pyenv/versions/tariq/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /root/.pyenv/versions/tariq/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /root/.pyenv/versions/tariq/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Iteration: 100%|██████████| 6/6 [00:00<00:00, 10.79it/s]
# Evaluating: 100%|██████████| 3/3 [00:00<00:00, 39.40it/s]
# /root/.pyenv/versions/tariq/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /root/.pyenv/versions/tariq/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /root/.pyenv/versions/tariq/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Epoch: 100%|██████████| 2/2 [00:01<00:00,  1.53it/s]
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mis['text_a'] = mis[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mis['text_a'] = mis[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mis['text_a'] = mis[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mis['text_a'] = mis[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mis['text_a'] = mis[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mis['text_a'] = mis[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mis['text_a'] = mis[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mis['text_a'] = mis[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mis['text_a'] = mis[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mis['text_a'] = mis[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mis['text_a'] = mis[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mis['text_a'] = mis[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mis['text_a'] = mis[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mis['text_a'] = mis[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mis['text_a'] = mis[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mis['text_a'] = mis[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mis['text_a'] = mis[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mis['text_a'] = mis[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mis['text_a'] = mis[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mis['text_a'] = mis[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mis['text_a'] = mis[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mis['text_a'] = mis[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mis['text_a'] = mis[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mis['text_a'] = mis[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mis['text_a'] = mis[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mis['text_a'] = mis[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mis['text_a'] = mis[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mis['text_a'] = mis[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mis['text_a'] = mis[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mis['text_a'] = mis[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mis['text_a'] = mis[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mis['text_a'] = mis[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mis['text_a'] = mis[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mis['text_a'] = mis[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mis['text_a'] = mis[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mis['text_a'] = mis[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mis['text_a'] = mis[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mis['text_a'] = mis[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mis['text_a'] = mis[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mis['text_a'] = mis[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mis['text_a'] = mis[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mis['text_a'] = mis[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mis['text_a'] = mis[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mis['text_a'] = mis[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mis['text_a'] = mis[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mis['text_a'] = mis[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mis['text_a'] = mis[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mis['text_a'] = mis[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mis['text_a'] = mis[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mis['text_a'] = mis[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mis['text_a'] = mis[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mis['text_a'] = mis[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mis['text_a'] = mis[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mis['text_a'] = mis[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mis['text_a'] = mis[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mis['text_a'] = mis[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mis['text_a'] = mis[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mis['text_a'] = mis[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mis['text_a'] = mis[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mis['text_a'] = mis[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...
#   mis['text_a'] = mis[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mis['text_a'] = mis[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mis['text_a'] = mis[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mis['text_a'] = mis[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mis['text_a'] = mis[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mis['text_a'] = mis[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mis['text_a'] = mis[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mis['text_a'] = mis[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mis['text_a'] = mis[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mis['text_a'] = mis[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mis['text_a'] = mis[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mis['text_a'] = mis[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mis['text_a'] = mis[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mis['text_a'] = mis[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mis['text_a'] = mis[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mis['text_a'] = mis[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mis['text_a'] = mis[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mis['text_a'] = mis[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mis['text_a'] = mis[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mis['text_a'] = mis[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mis['text_a'] = mis[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mis['text_a'] = mis[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mis['text_a'] = mis[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mis['text_a'] = mis[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mis['text_a'] = mis[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mis['text_a'] = mis[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mis['text_a'] = mis[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mis['text_a'] = mis[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mis['text_a'] = mis[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mis['text_a'] = mis[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mis['text_a'] = mis[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mis['text_a'] = mis[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mis['text_a'] = mis[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mis['text_a'] = mis[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mis['text_a'] = mis[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mis['text_a'] = mis[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# /root/workspace/IPM-main/src/ipm_multi_v5_with_fixed.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mis['text_a'] = mis[cols].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)
# Saved summary to: /root/workspace/IPM-main/Dynamic_data/mammogram/70_30/fixed_one_third_step_10%/IPM_evaluations_fixed_mammogram_584_one_third_step_10%_70_30.csv
